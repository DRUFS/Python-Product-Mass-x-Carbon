# %%
import pymannkendall as mk
import pandas as pd
import numpy as np
import xarray as xr
import pooch
import datetime
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter, MonthLocator, YearLocator
from matplotlib import pyplot as plt
from matplotlib import style
from numpy import mean
from mpl_toolkits import mplot3d
import seaborn as sns
from scipy import stats
import matplotlib.image as mpimg
# %matplotlib inline

from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from matplotlib.ticker import ScalarFormatter

from scipy.stats import t

plt.style.use("bmh")

CompileCheck = " ^ Compiled ^ ";

CompileCheck

#summaryStats
# Out:
# ' ^ Compiled ^ '

# %%
pcfii = pd.read_csv("HW5_PCFii.csv")

pcfi = pd.read_csv("HW5_PCF.csv")

pcfi1 = pd.read_csv("HW5_PCFilter.csv")

CompileCheck

#pcfi.dropna()

print(500/ 5)

print(500/ 2)

print(500/ 50)

print(500/ 8000)

print("-----")

print(4/ 5)

print(4/ 2)

print(4/ 50)

print(4/ 8000)

#pcfi1.UpstreamCO2
# Out:
# 100.0
# 250.0
# 10.0
# 0.0625
# -----
# 0.8
# 2.0
# 0.08
# 0.0005

# %%
#pcf.fillna(method ='pad')

#pcf.isnull().values.any()

#pcf.fillna(method = 'ffill', inplace = True)

#display(pcf)

# df_filtered = df[df['Age'] >= 25]

pcfi = pcfi[pcfi.Weight <= 10000]
pcfi1 = pcfi1[pcfi1.Weight <= 10000]

# %% [markdown]
# Weight x PCF pre

# %%
# # *****************
# # # Weight x PCF
# # ****************

# fig, ax = plt.subplots(figsize = (24, 9))

# scatter1 = ax.scatter(pcfWeightLow.Weight, pcfWeightLow.PCF,
#     c = pcfWeightLow.PCF, #"red", #( df4["pm2.5"] * 4),
# # scatter1 = ax.scatter(pcfWeightHigh.Weight, pcfWeightHigh.PCF,
# #     c = pcfWeightHigh.PCF, #"red", #( df4["pm2.5"] * 4),
#     cmap = "Accent",
#     alpha = .99,
#     #linewidths = None,
#     edgecolors = "navy",
#     lw = 1.,
#     label = 'Product'
# )

# cbar = plt.colorbar(scatter1, location = "right", pad = 0.005, aspect = 50)#shrink = .8)

# ################################################################################################################################################
# # Linear Regression
# ################################################################################################################################################

# slope, intercept, r_value, p_value, stderr = stats.linregress(pcfWeightLow.Weight, pcfWeightLow.PCF, alternative = "less")

# reg = ax.plot(pcfWeightLow.Weight, intercept + (slope * pcfWeightLow.Weight), color = "crimson", ls = 'dashdot', lw = 3, label = 'Linear Regression')


# ################################################################################################################################################
# # Labels
# ################################################################################################################################################
# ax.legend()
# plt.legend(fontsize = 14, labelcolor = 'black', loc = "upper right")

# ax.set_title("Product Weight x Product Carbon Footprint", fontweight = "bold", fontsize = 30, horizontalalignment = 'center', color = 'black')
# ax.set_xlabel("Product Weight (kg)",  fontsize = 25, labelpad = 30, color = 'black')
# ax.set_ylabel("Product Carbon Footprint (kg $CO_{2e})$", fontsize = 25, labelpad = 30, color = 'black')

# ################################################################################################################################################
# # Ticks
# ################################################################################################################################################

# ax.xaxis.set_minor_formatter(ScalarFormatter())
# ax.yaxis.set_minor_formatter(ScalarFormatter())

# ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 12)#, length = 550, zorder = 4, width = .4)
# ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 10)#, length = 550, zorder = 4, width = .4)


# ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 40)#, align = "right", rotation_mode = "anchor")#, width = .4)

# ax.minorticks_on()

# plt.xticks(fontsize = 12, ha = "left")
# plt.yticks(fontsize = 12, ha = "right")

# ################################################################################################################################################
# # Margins, Grid
# ################################################################################################################################################

# plt.rcParams['axes.axisbelow'] = True
# plt.rc('axes', axisbelow = True)
# ax.set_axisbelow(True)

# ax.margins(x = 0.01)
# ax.margins(y = 0.02)

# ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
# ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
# ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)


# fig.tight_layout()

# plt.show();


# ################################################################################################################################################
# # Description
# ################################################################################################################################################

# print("\nPCF: \n")

# print("SLOPE: %f \nINTERCEPT: %f" % (slope, intercept))
# print(f"Coefficient of Determination (r squared): { r_value ** 2:.3f}")
# print(f"Slope: {slope:.5f}")
# print(f"R-Value: {r_value:.2f}")
# print(f"Intercept: {intercept:.2f}")
# print(f"P-Value: {p_value:.2f}")
# print(f"Standard Error: {stderr:.2f}")
# print(f"Mean: ", np.mean(pcfWeightLow.Weight))
# print(f"Mean Concentration: ", round(np.mean(pcfWeightLow.PCF), 3))
# print(f"Standard Deviation: ", np.std(pcfWeightLow.Weight))
# print(f"Standard Deviation Concentration: ", round(np.std(pcfWeightLow.PCF), 3), "\n")

# ################################################################################################################################################

# tau, p_value = stats.kendalltau(pcfWeightLow.Weight, pcfWeightLow.PCF)
# print("Tau: ", tau)
# print("P-Value: ", p_value)

# ################################################################################################################################################

# ken = mk.original_test(pcfWeightLow.PCF/pcfWeightLow.Weight)
# print(ken)

# %% [markdown]
# Weight x CI pre

# %%
# # *****************
# # # Weight x CI
# # ****************

# fig, ax = plt.subplots(figsize = (24, 9))

# scatter1 = ax.scatter(pcfWeightLow.Weight, pcfWeightLow.CarbonIntensity,
#     c = pcfWeightLow.CarbonIntensity, #"red", #( df4["pm2.5"] * 4),
# # scatter1 = ax.scatter(pcfWeightHigh.Weight, pcfWeightHigh.CarbonIntensity,
# #     c = pcfWeightHigh.CarbonIntensity, #"red", #( df4["pm2.5"] * 4),
#     cmap = "Dark2",
#     alpha = 0.6,
#     #linewidths = None,
#     edgecolors = "k",
#     lw = 1.
# )

# cbar = plt.colorbar(scatter1, location = "right", pad = 0.005, aspect = 50)#shrink = .8)

# ax.legend(['Product'], fontsize = 12, labelcolor = 'black', loc = "upper right")

# ax.set_title("Product Weight $(kg)$ x Carbon Intensity", fontweight = "bold", fontsize = 30, horizontalalignment = 'center', color = 'black')
# ax.set_xlabel("Product Weight (kg)",  fontsize = 25, labelpad = 30, color = 'black')
# ax.set_ylabel("Carbon Intensity", fontsize = 25, labelpad = 30, color = 'black')

# ################################################################################################################################################
# # Ticks
# ################################################################################################################################################

# ax.xaxis.set_minor_formatter(ScalarFormatter())
# ax.yaxis.set_minor_formatter(ScalarFormatter())

# ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 12)#, length = 550, zorder = 4, width = .4)
# ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 10)#, length = 550, zorder = 4, width = .4)

# ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 40)#, align = "right", rotation_mode = "anchor")#, width = .4)

# ax.minorticks_on()

# plt.xticks(fontsize = 12, ha = "left")
# plt.yticks(fontsize = 12, ha = "right")

# ################################################################################################################################################
# # Margins, Grid
# ################################################################################################################################################

# plt.rcParams['axes.axisbelow'] = True
# plt.rc('axes', axisbelow = True)
# ax.set_axisbelow(True)

# ax.margins(x = 0.01)
# ax.margins(y = 0.02)

# ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
# ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
# ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)

# fig.tight_layout()

# plt.show();

# %%
# fig, ax = plt.subplots(2, 1, figsize = (25, 12))

# scatter1 = ax[0].scatter(pcfWeightLow.Weight, pcfWeightLow.PCF,
#     c = pcfWeightLow.PCF, #"red", #( df4["pm2.5"] * 4),
#     cmap = "Dark2",
#     alpha = 0.6,
#     #linewidths = None,
#     edgecolors = "k",
#     lw = 1.
# )

# ax[0].cbar = plt.colorbar(scatter1, location = "right", pad = 0.005, aspect = 50)#shrink = .8)

# ax[0].legend(['Product'], fontsize = 12, labelcolor = 'black', loc = "upper right")

# ax[0].set_title("Product Weight $(kg)$ x Product Carbon Footprint $(kg$ $CO_{2})$", fontweight = "bold", fontsize = 30, horizontalalignment = 'center', color = 'black')
# ax[0].set_xlabel("Product Weight (kg)",  fontsize = 25, labelpad = 30, color = 'black')
# ax[0].set_ylabel("Product Carbon Footprint (kg $CO_{2})$", fontsize = 25, labelpad = 30, color = 'black')

# ################################################################################################################################################
# # Ticks
# ################################################################################################################################################

# ax[0].xaxis.set_minor_formatter(ScalarFormatter())
# ax[0].yaxis.set_minor_formatter(ScalarFormatter())

# ax[0].tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 12)#, length = 550, zorder = 4, width = .4)
# ax[0].tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 10)#, length = 550, zorder = 4, width = .4)


# ax[0].tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 40)#, align = "right", rotation_mode = "anchor")#, width = .4)

# ax[0].minorticks_on()

# ax[0].xticks(fontsize = 12, ha = "left")
# ax[0].yticks(fontsize = 12, ha = "right")

# ################################################################################################################################################
# # Margins, Grid
# ################################################################################################################################################

# ax[0].rcParams['axes.axisbelow'] = True
# ax[0].rc('axes', axisbelow = True)
# ax[0].set_axisbelow(True)

# ax[0].margins(x = 0.01)
# ax[0].margins(y = 0.02)

# ax[0].grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
# ax[0].grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
# ax[0].grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)

# fig.tight_layout()

# plt.show();

# %%
# fig = plt.figure(figsize = (30, 12))

# ax = plt.axes(projection = '3d')

# x = pcfWeightLow.Weight
# y = pcfWeightLow.PCF
# z = pcfWeightLow.CarbonIntensity

# ax.view_init(40, 70)

# ax.scatter(x, y, z, zdir= 'z', depthshade = True, #, s = (pcfWeightLow.CarbonIntensity * .009),
#     c = (pcfWeightLow.CarbonIntensity * .8),
#     cmap = "Paired_r",
#     alpha = 0.9,
#     #linewidths = None,
#     edgecolors = "navy",)

# ax.invert_zaxis()

# ax.set_xlabel('Weight')
# ax.set_ylabel('Product Carbon Footprint')
# ax.set_zlabel('Carbon Intensity')
# ax.set_title('3D: Daily Temperature x PM Concentration')

# plt.show()

# %%
# fig, ax = plt.subplots(figsize = (25, 12))

# scatter1 = ax.scatter(pcf.Year, pcf.CarbonIntensity,
#     c = pcf.CarbonIntensity, #"red", #( df4["pm2.5"] * 4),
# # scatter1 = ax.scatter(pcfWeightHigh.Weight, pcfWeightHigh.PCF,
# #     c = pcfWeightHigh.PCF, #"red", #( df4["pm2.5"] * 4),
#     cmap = "Accent",
#     alpha = .99,
#     #linewidths = None,
#     edgecolors = "navy",
#     lw = 1.
# )

# cbar = plt.colorbar(scatter1, location = "right", pad = 0.005, aspect = 50)#shrink = .8)

# ax.legend(['Product'], fontsize = 13, labelcolor = 'r', loc = "upper right")

# ax.set_title("Product Weight x Product Carbon Footprint", fontweight = "bold", fontsize = 30, horizontalalignment = 'center', color = 'black')
# ax.set_xlabel("Product Weight (kg)",  fontsize = 25, labelpad = 30, color = 'black')
# ax.set_ylabel("Product Carbon Footprint (kg $CO_{2e})$", fontsize = 25, labelpad = 30, color = 'black')

# ################################################################################################################################################
# # Ticks
# ################################################################################################################################################

# ax.xaxis.set_minor_formatter(ScalarFormatter())
# ax.yaxis.set_minor_formatter(ScalarFormatter())

# ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 12)#, length = 550, zorder = 4, width = .4)
# ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 10)#, length = 550, zorder = 4, width = .4)


# ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 40)#, align = "right", rotation_mode = "anchor")#, width = .4)

# ax.minorticks_on()

# plt.xticks(fontsize = 12, ha = "left")
# plt.yticks(fontsize = 12, ha = "right")

# ################################################################################################################################################
# # Margins, Grid
# ################################################################################################################################################

# plt.rcParams['axes.axisbelow'] = True
# plt.rc('axes', axisbelow = True)
# ax.set_axisbelow(True)

# ax.margins(x = 0.01)
# ax.margins(y = 0.02)

# ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
# ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
# ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)

# fig.tight_layout()

# plt.show();

# %% [markdown]
# Weight x PCF new

# %%
# *****************
# # Weight x PCF
# ****************

fig, ax = plt.subplots(figsize = (25, 12))

scatter1 = ax.scatter(pcfi.Weight, pcfi.PCF,
    c = pcfi.PCF, #s = pcfWeightLow.PCF * .0008,#"red", #( df4["pm2.5"] * 4),
# scatter1 = ax.scatter(pcfWeightHigh.Weight, pcfWeightHigh.PCF,
#     c = pcfWeightHigh.PCF, #"red", #( df4["pm2.5"] * 4),
    cmap = "Dark2",
    alpha = .99,
    #linewidths = None,
    edgecolors = "k",
    lw = .5,
    label = 'Product'
)

cbar = plt.colorbar(scatter1, location = "right", pad = 0.005, aspect = 50)#shrink = .8)

################################################################################################################################################
# Linear Regression
################################################################################################################################################

xWeight = pcfi.Weight
yPCF = pcfi.PCF

# slope, intercept, rvalue, pvalue, stderr = stats.linregress(x1, y1)
# result = stats.linregress(x1, y1)
# reg = ax.plot(pcfWeightLow.Weight, intercept + (slope * pcfWeightLow.Weight), color = "crimson", ls = 'dashdot', lw = 3, label = 'Linear Regression')

tRes1 = stats.linregress(xWeight, yPCF)
#print(f"R-squared: {tRes.rvalue**2:.6f}")
formWeightPCF = tRes1.slope * xWeight
plt.plot(xWeight, tRes1.intercept + formWeightPCF, 'r', ls = 'dashdot', lw = 1.5,  label = 'Linear Regression') #color = "crimson", 


# tinv = lambda p, df: abs(t.ppf(p/2, df))
# ts = tinv(0.05, len(x)-2)
# print(f"slope (95%): {tRes.slope:.6f} +/- {ts*tRes.stderr:.6f}")
# print(f"intercept (95%): {tRes.intercept:.6f}"
#       f" +/- {ts*tRes.intercept_stderr:.6f}")
# print(f"P-Value: {tRes.pvalue}")

################################################################################################################################################
# Labels
################################################################################################################################################
ax.legend()
plt.legend(fontsize = 14, labelcolor = 'black', loc = "upper right")

ax.set_title("Product Weight x Product Carbon Footprint", fontweight = "bold", fontsize = 30, horizontalalignment = 'center', color = 'black')
ax.set_xlabel("Product Weight (kg)",  fontsize = 25, labelpad = 30, color = 'black')
ax.set_ylabel("Product Carbon Footprint (kg $CO_{2e})$", fontsize = 25, labelpad = 30, color = 'black')

################################################################################################################################################
# Ticks
################################################################################################################################################

ax.xaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_minor_formatter(ScalarFormatter())

ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 12)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 10)#, length = 550, zorder = 4, width = .4)


ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 40)#, align = "right", rotation_mode = "anchor")#, width = .4)

ax.minorticks_on()

plt.xticks(fontsize = 12, ha = "left")
plt.yticks(fontsize = 12, ha = "right")

################################################################################################################################################
# Margins, Grid
################################################################################################################################################

plt.rcParams['axes.axisbelow'] = True
plt.rc('axes', axisbelow = True)
ax.set_axisbelow(True)

ax.margins(x = 0.01)
ax.margins(y = 0.02)

ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)

fig.tight_layout()

plt.show();


################################################################################################################################################
# Description
################################################################################################################################################

print("\n Weight x PCF\n")

print("SLOPE: %f \nINTERCEPT: %f" % (tRes1.slope, tRes1.intercept))
print(f"Coefficient of Determination (r squared): { tRes1.rvalue ** 2:.3f}")
print(f"Slope: {tRes1.slope:.5f}")
print(f"R-Value: {tRes1.rvalue:.2f}")
print(f"Intercept: {tRes1.intercept:.2f}")
print(f"P-Value: {tRes1.pvalue:.8f}")
print(f"Standard Error: {tRes1.stderr:.2f}")
print(f"Mean Weight: ", round(np.mean(pcfi.Weight), 2), "kg")
print(f"Mean PCF: ", round(np.mean(pcfi.PCF), 3), "kg CO2")
print(f"Standard Deviation - Weight: ", round(np.std(pcfi.Weight), 2), "kg")
print(f"Standard Deviation - PCF: ", round(np.std(pcfi.PCF), 3), "kg CO2", "\n")

# ################################################################################################################################################
# tau, p_value = stats.kendalltau(pcfWeightLow.Weight, pcfWeightLow.PCF)
# print("Tau: ", tau)
# print("P-Value: ", p_value)
# ################################################################################################################################################
# ken = mk.original_test(tRes)
# print(ken)

# print(stats.ttest_ind(x1,y1))
# Out:
#  Weight x PCF
#
# SLOPE: 13.689558
# INTERCEPT: -588.045389
# Coefficient of Determination (r squared): 0.371
# Slope: 13.68956
# R-Value: 0.61
# Intercept: -588.05
# P-Value: 0.00000000
# Standard Error: 0.61
# Mean Weight:  347.27 kg
# Mean PCF:  4165.919 kg CO2
# Standard Deviation - Weight:  566.48 kg
# Standard Deviation - PCF:  12735.18 kg CO2

# %% [markdown]
# Weight x CI New

# %%
fig, ax = plt.subplots(figsize = (25, 12))

scatter2 = ax.scatter(pcfi.Weight, pcfi.CarbonIntensity,
    c = pcfi.CarbonIntensity, #s = pcfWeightLow.PCF * .0008,#"red", #( df4["pm2.5"] * 4),
# scatter1 = ax.scatter(pcfWeightHigh.Weight, pcfWeightHigh.PCF,
#     c = pcfWeightHigh.PCF, #"red", #( df4["pm2.5"] * 4),
    cmap = "tab10",
    alpha = .99,
    #linewidths = None,
    edgecolors = "navy",
    lw = .5,
    label = 'Product'
)

cbar = plt.colorbar(scatter2, location = "right", pad = 0.005, aspect = 50)#shrink = .8)

################################################################################################################################################
# Linear Regression
################################################################################################################################################

xWeight = pcfi.Weight
yCI = pcfi.CarbonIntensity

# xWeight = np.linspace(0, 3500, .1)
# yCI = np.linspace(0, 3500, .1)
# slope, intercept, rvalue, pvalue, stderr = stats.linregress(x1, y1)
# result = stats.linregress(x1, y1)
# reg = ax.plot(pcfWeightLow.Weight, intercept + (slope * pcfWeightLow.Weight), color = "crimson", ls = 'dashdot', lw = 3, label = 'Linear Regression')

tRes2 = stats.linregress(xWeight, yCI)
#print(f"R-squared: {tRes.rvalue**2:.6f}")
formWeightCI = (tRes2.slope * xWeight)
plt.plot(xWeight, tRes2.intercept + formWeightCI, 'r', ls = 'dashdot', lw = 1.5,  label = 'Linear Regression') #color = "crimson", 

# tinv = lambda p, df: abs(t.ppf(p/2, df))
# ts = tinv(0.05, len(x)-2)
# print(f"slope (95%): {tRes.slope:.6f} +/- {ts*tRes.stderr:.6f}")
# print(f"intercept (95%): {tRes.intercept:.6f}"
#       f" +/- {ts*tRes.intercept_stderr:.6f}")
# print(f"P-Value: {tRes.pvalue}")

################################################################################################################################################
# Labels
################################################################################################################################################
ax.legend()
plt.legend(fontsize = 14, labelcolor = 'black', loc = "upper right")

ax.set_title("Product Weight x Carbon Intensity", fontweight = "bold", fontsize = 30, horizontalalignment = 'center', color = 'black')
ax.set_xlabel("Product Weight (kg)",  fontsize = 25, labelpad = 30, color = 'black')
ax.set_ylabel("Carbon Intensity", fontsize = 25, labelpad = 30, color = 'black')

################################################################################################################################################
# Ticks
################################################################################################################################################

ax.xaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_minor_formatter(ScalarFormatter())

ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 12)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 10)#, length = 550, zorder = 4, width = .4)

ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 40)#, align = "right", rotation_mode = "anchor")#, width = .4)

ax.minorticks_on()

plt.xticks(fontsize = 12, ha = "left")
plt.yticks(fontsize = 12, ha = "right")

################################################################################################################################################
# Margins, Grid
################################################################################################################################################

plt.rcParams['axes.axisbelow'] = True
plt.rc('axes', axisbelow = True)
ax.set_axisbelow(True)

ax.margins(x = 0.01)
ax.margins(y = 0.02)

ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)

#plt.ylim([-15, 1000])

fig.tight_layout()

plt.show();

################################################################################################################################################
# Description
################################################################################################################################################

print("\nWeight x CI \n")

print("SLOPE: %f \nINTERCEPT: %f" % (tRes2.slope, tRes2.intercept))
print(f"Coefficient of Determination (r squared): { tRes2.rvalue ** 2:.3f}")
print(f"Slope: {tRes2.slope:.5f}")
print(f"R-Value: {tRes2.rvalue:.2f}")
print(f"Intercept: {tRes2.intercept:.2f}")
print(f"P-Value: {tRes2.pvalue:.8f}")
print(f"Standard Error: {tRes2.stderr:.2f}")
print(f"Mean - Weight: ", round(np.mean(pcfi.Weight), 2), "kg")
print(f"Mean - CarbonIntensity: ", round(np.mean(pcfi.CarbonIntensity), 3), "kg CO2")
print(f"Standard Deviation - Weight: ", round(np.std(pcfi.Weight), 2), "kg")
print(f"Standard Deviation - CarbonIntensity: ", round(np.std(pcfi.CarbonIntensity), 3), "kg CO2", "\n")

# ################################################################################################################################################

# tau, p_value = stats.kendalltau(pcfWeightLow.Weight, pcfWeightLow.PCF)
# print("Tau: ", tau)
# print("P-Value: ", p_value)

# ################################################################################################################################################

# ken = mk.original_test(tRes)
# print(ken)

# print(stats.ttest_ind(x1,y1))
# Out:
# Weight x CI
#
# SLOPE: -0.024347
# INTERCEPT: 42.948603
# Coefficient of Determination (r squared): 0.026
# Slope: -0.02435
# R-Value: -0.16
# Intercept: 42.95
# P-Value: 0.00000197
# Standard Error: 0.01
# Mean - Weight:  347.27 kg
# Mean - CarbonIntensity:  34.494 kg CO2
# Standard Deviation - Weight:  566.48 kg
# Standard Deviation - CarbonIntensity:  85.117 kg CO2

# %%
fig, ax = plt.subplots(figsize = (7, 10)) 

xO = pcfi1.Weight
#xO = pcfi.CarbonIntensity
yO = pcfi1.UpstreamCO2
yOO = pcfi1.OperationsCO2
yOOO = pcfi1.DownstreamCO2

#filled = pd.Series(x).fillna(limit=500, method='ffill')
#yO = pd.Series(yO).fillna(limit = 1000, method='ffill')

scatteri = ax.scatter(xO, yO, #s = (xO * .8),
    c = pcfi1.UpstreamCO2, #(yO * 1.8),
    #cmap = "CMRmap_r",
    #cmap = "rainbow",
    #cmap = "twilight_shifted",
    #cmap = "gist_ncar_r",
    cmap = "Dark2",
    alpha = 0.6,
    #linewidths = None,
    edgecolors = "k",
    label = "Product",
)

cbar = plt.colorbar(scatteri, location = "right", pad = 0.009, aspect = 70, shrink = .888)

#****************************** Linear Regression ******************************
reg3 = stats.linregress(xO, yO)

xval = np.linspace(xO.min(),xO.max())
line = reg3.intercept + (reg3.slope * xval)  # This is the critical ch
#plt.plot(yval, line, 'r', label="Regression Line", antialiased=True)
plt.plot(xval, line, 'r', ls = 'dashdot', lw = 1.5,  label = 'Linear Regression') #color = "crimson", 

ax.legend()
ax.legend(fontsize = 8, labelcolor = 'black', loc = "upper right")

#****************************** Labels ******************************
ax.set_title('Product Weight x Upstream $CO_{2e}$', fontweight = "bold", fontsize = 14, horizontalalignment = 'center', color = 'black')
ax.set_xlabel('Product Weight (kg)',  fontsize = 12, labelpad = 15, color = 'black')
ax.set_ylabel('Upstream $CO_{2e}$ (Fraction of Total PCF)', fontsize = 12, labelpad = 15, color = 'black')

#****************************** Tick Marks, Grid,& Labels ******************************
ax.xaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 8)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 8)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 20)#, align = "right", rotation_mode = "anchor")#, width = .4)
ax.minorticks_on()
plt.xticks(fontsize = 10, ha = "left")
plt.yticks(fontsize = 10, ha = "right")

plt.rcParams['axes.axisbelow'] = True
plt.rc('axes', axisbelow = True)
ax.set_axisbelow(True)

ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)
#****************************** ****************************** ******************************
plt.ylim([-0.01, 1.05])
plt.tight_layout()
plt.show()

#****************************** Feedback ******************************

print("\nProduct Weight x Upstream CO2 \n")

print("SLOPE: %f \nINTERCEPT: %f" % (reg3.slope, reg3.intercept))
print(f"Coefficient of Determination (r squared): {reg3.rvalue ** 2:.3f}")
print(f"Slope: {reg3.slope:.5f}")
print(f"R-Value: {reg3.rvalue:.2f}")
print(f"Intercept: {reg3.intercept:.2f}")
print(f"P-Value: {reg3.pvalue:.8f}")
print(f"Standard Error: {reg3.stderr:.2f}")
print(f"Mean - Weight: ", round(np.mean(xO),2), "kg")
print(f"Mean - Upstream CO2: ", round(np.mean(yO), 3), "kg CO2")
print(f"Standard Deviation - Weight: ", round(np.std(xO), 2), "kg")
print(f"Standard Deviation - Upstream CO2: ", round(np.std(yO), 3), "kg CO2", "\n")
# Out:
# Product Weight x Upstream CO2
#
# SLOPE: -0.000076
# INTERCEPT: 0.464557
# Coefficient of Determination (r squared): 0.012
# Slope: -0.00008
# R-Value: -0.11
# Intercept: 0.46
# P-Value: 0.02588444
# Standard Error: 0.00
# Mean - Weight:  249.6 kg
# Mean - Upstream CO2:  0.446 kg CO2
# Standard Deviation - Weight:  445.85 kg
# Standard Deviation - Upstream CO2:  0.308 kg CO2

# %% [markdown]
# CI x Operations

# %%
fig, ax = plt.subplots(figsize = (7, 10)) 

xO = pcfi1.Weight
#xO = pcfi.CarbonIntensity
yO = pcfi1.UpstreamCO2
yOO = pcfi1.OperationsCO2
yOOO = pcfi1.DownstreamCO2

scatterii = ax.scatter(xO, yOO, #s = 20,#,(xO * .8),
    c = yOO,
    #cmap = "nipy_spectral_r","
    cmap = "Dark2_r",
    alpha = 0.6,
    #linewidths = None,
    edgecolors = "navy",
    label = "Product"
)

#****************************** Linear Regression ******************************
reg2 = stats.linregress(xO, yOO)#,  alternative = "less")
# reg2 = stats.linregress(xO, yOO)
# reg3 = stats.linregress(xO, yOOO)

plt.plot(xO, reg2.intercept + (reg2.slope * xO), 'r', ls = 'dashdot', lw = 1.5,  label = 'Linear Regression') #color = "crimson", 
#ax[1].plot(xO, reg2.intercept + p2, 'r', color = "crimson", ls = 'dashdot', lw = 1.5,  label = 'Linear Regression')
#ax[2].plot(xO, reg3.intercept + p3, 'r', color = "crimson", ls = 'dashdot', lw = 1.5,  label = 'Linear Regression')
# use the previously defined function

ax.legend()
plt.legend(fontsize = 8, labelcolor = 'black', loc = "upper right", fancybox = True)

plt.colorbar(scatterii, location = "right", pad = 0.009, aspect = 70, shrink = .999)

#****************************** Labels ******************************
ax.set_title('Product Weight x Operations $CO_{2e}$', fontweight = "bold", fontsize = 14, horizontalalignment = 'center', color = 'black')
ax.set_xlabel('Product Weight (kg)',  fontsize = 12, labelpad = 15, color = 'black')
ax.set_ylabel('Operations $CO_{2e}$ (Fraction of Total PCF)', fontsize = 12, labelpad = 15, color = 'black')

#****************************** Tick Marks, Grid,& Labels ******************************
ax.xaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 8)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 8)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 20)#, align = "right", rotation_mode = "anchor")#, width = .4)
ax.minorticks_on()
plt.xticks(fontsize = 10, ha = "left")
plt.yticks(fontsize = 10, ha = "right")

plt.rcParams['axes.axisbelow'] = True
plt.rc('axes', axisbelow = True)
ax.set_axisbelow(True)

ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)
#******************************************************************************************

plt.ylim([-0.01, 1.01])

plt.tight_layout()
plt.show()

#****************************** Feedback ******************************

print("\nProduct Weight x Operations CO2 \n")

print("SLOPE: %f \nINTERCEPT: %f" % (reg2.slope, reg2.intercept))
print(f"Coefficient of Determination (r squared): {reg2.rvalue ** 2:.3f}")
print(f"Slope: {reg2.slope:.5f}")
print(f"R-Value: {reg2.rvalue:.2f}")
print(f"Intercept: {reg2.intercept:.2f}")
print(f"P-Value: {reg2.pvalue:.8f}")
print(f"Standard Error: {reg2.stderr:.2f}")
print(f"Mean - Product Weight: ", round(np.mean(xO), 2) , "kg")
print(f"Mean - Operations CO2: ", round(np.mean(yOO), 3), "kg CO2")
print(f"Standard Deviation - Product Weight: ", round(np.std(xO), 2), "kg")
print(f"Standard Deviation - Operations CO2: ", round(np.std(yOO), 3), "kg CO2", "\n")
# Out:
# Product Weight x Operations CO2
#
# SLOPE: 0.000222
# INTERCEPT: 0.177249
# Coefficient of Determination (r squared): 0.145
# Slope: 0.00022
# R-Value: 0.38
# Intercept: 0.18
# P-Value: 0.00000000
# Standard Error: 0.00
# Mean - Product Weight:  249.6 kg
# Mean - Operations CO2:  0.233 kg CO2
# Standard Deviation - Product Weight:  445.85 kg
# Standard Deviation - Operations CO2:  0.26 kg CO2

# %% [markdown]
# CI x Downstream

# %%
fig, ax = plt.subplots(figsize = (7, 10)) 

xO = pcfi1.Weight
#xO = pcfi.CarbonIntensity
yO = pcfi1.UpstreamCO2
yOO = pcfi1.OperationsCO2
yOOO = pcfi1.DownstreamCO2


scatteriii = ax.scatter(xO, yOOO, #s = (xO * .8),
    c = yOOO, #(xO * 1.8),
    cmap = "Set1_r",
    alpha = 0.6,
    #linewidths = None,
    ec = "k",
    label = "Product"
)

cbar = plt.colorbar(scatteriii, location = "right", pad = 0.009, aspect = 70, shrink = .999)

#****************** Linear Regression ********************************************
reg3 = stats.linregress(xO, yOOO)
# reg2 = stats.linregress(xO, yOO)
# reg3 = stats.linregress(xO, yOOO)

plt.plot(xO, reg3.intercept + (reg3.slope * xO), 'r', ls = 'dashdot', lw = 1.5,  label = 'Linear Regression') #color = "crimson", 
#ax[1].plot(xO, reg2.intercept + p2, 'r', color = "crimson", ls = 'dashdot', lw = 1.5,  label = 'Linear Regression')
#ax[2].plot(xO, reg3.intercept + p3, 'r', color = "crimson", ls = 'dashdot', lw = 1.5,  label = 'Linear Regression')
# use the previously defined function

ax.legend()
plt.legend(fontsize = 8, labelcolor = 'black', loc = "upper right")

#******************#****************** Labels #******************#******************#******************
# ax.set_xlabel('Carbon Intensity')
# ax.set_ylabel('Downstream $CO_{2e}$ (Fraction of Total PCF)')
# ax.set_title('Downstream $CO_{2e}$ x Carbon Intensity')

ax.set_title('Product Weight x Downstream $CO_{2e}$', fontweight = "bold", fontsize = 14, horizontalalignment = 'center', color = 'black')
ax.set_xlabel('Product Weight (kg)',  fontsize = 12, labelpad = 15, color = 'black')
ax.set_ylabel('Downstream $CO_{2e}$ (Fraction of Total PCF)', fontsize = 12, labelpad = 15, color = 'black')

#****************** Ticks, Grid, & Labels #******************#******************#******************#******************#******************
ax.xaxis.set_minor_formatter(ScalarFormatter())
ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.tick_params(axis = "x", which = "minor", rotation = 35, colors = "maroon", direction = "in", labelsize = 8)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = "y", which = "minor", rotation = 0, colors = "maroon", direction = "in", labelsize = 8)#, length = 550, zorder = 4, width = .4)
ax.tick_params(axis = 'x', which = "major", colors = 'navy', rotation = 0, labelcolor = "black", direction = "out", length = 20)#, align = "right", rotation_mode = "anchor")#, width = .4)
ax.minorticks_on()
plt.xticks(fontsize = 10, ha = "left")
plt.yticks(fontsize = 10, ha = "right")

plt.rcParams['axes.axisbelow'] = True
plt.rc('axes', axisbelow = True)
ax.set_axisbelow(True)

ax.grid(which = 'both', axis = "y", color = "black", ls = '-', lw = .25)
ax.grid(which = 'minor', axis = "x", color = "gray", ls = '-', lw = .6, alpha = .5)
ax.grid(which = 'major', axis = "x", color = "black", ls = '-', lw = .6, alpha = .5)
#******************#******************#******************#******************#******************#******************

plt.ylim([-0.01, 1.05])

plt.tight_layout()
plt.show()

#********

print("\nProduct Weight x Downstream CO2 \n")

print("SLOPE: %f \nINTERCEPT: %f" % (reg3.slope, reg3.intercept))
print(f"Coefficient of Determination (r squared): {reg3.rvalue ** 2:.3f}")
print(f"Slope: {reg3.slope:.5f}")
print(f"R-Value: {reg3.rvalue:.2f}")
print(f"Intercept: {reg3.intercept:.2f}")
print(f"P-Value: {reg3.pvalue:.8f}")
print(f"Standard Error: {reg3.stderr:.2f}")
print(f"Mean - Product Weight: ", round(np.mean(xO), 2), "kg")
print(f"Mean - Downstream CO2: ", round(np.mean(yOOO), 3), "kg CO2")
print(f"Standard Deviation - Product Weight: ", round(np.std(xO), 2), "kg")
print(f"Standard Deviation - Downstream CO2: ", round(np.std(yOOO), 3), "kg CO2", "\n")
# Out:
# Product Weight x Downstream CO2
#
# SLOPE: -0.000146
# INTERCEPT: 0.357491
# Coefficient of Determination (r squared): 0.037
# Slope: -0.00015
# R-Value: -0.19
# Intercept: 0.36
# P-Value: 0.00007733
# Standard Error: 0.00
# Mean - Product Weight:  249.6 kg
# Mean - Downstream CO2:  0.321 kg CO2
# Standard Deviation - Product Weight:  445.85 kg
# Standard Deviation - Downstream CO2:  0.337 kg CO2

# %%
xO = pcfi1.Weight
#xO = pcfi.CarbonIntensity
yO = pcfi1.UpstreamCO2
yOO = pcfi1.OperationsCO2
yOOO = pcfi1.DownstreamCO2

fig = plt.figure(figsize = (30, 12))

ax = plt.axes(projection = '3d')

#x = pcfi1.UpstreamCO2
x = pcfi1.UpstreamCO2
y = pcfi1.OperationsCO2
z = pcfi1.DownstreamCO2

ax.view_init(20, 70)

chch = ax.scatter(x, y, z, zdir= 'z', #, depthshade = True, #, s = (pcfWeightLow.CarbonIntensity * .009),
    c = (xO),
    cmap = "Dark2",
    alpha = 0.9,
    #linewidths = None,
    edgecolors = "navy",
    lw = .7
)

cbar = plt.colorbar(chch, location = "right", pad = 0.009, aspect = 70, shrink = .9, label = "Product Weight (kg)")

#ax.invert_xaxis()

ax.set_xlabel('Upstream $CO_{2e}$ (Fraction of Total PCF)', fontsize = 12, labelpad = 15, color = 'black')
ax.set_ylabel('Operations $CO_{2e}$ (Fraction of Total PCF)', fontsize = 12, labelpad = 15, color = 'black')
ax.set_zlabel('Downstream $CO_{2e}$ (Fraction of Total PCF)', fontsize = 12, labelpad = 15, color = 'black')
ax.set_title('3D - 4 Variable - Product Weight x Upstream | Downstream | Operations $CO_{2e}$', fontweight = "bold", fontsize = 14, horizontalalignment = 'center', color = 'black')

plt.show()
